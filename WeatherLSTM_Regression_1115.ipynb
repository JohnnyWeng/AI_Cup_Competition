# %% [markdown]
# # 資料整理和匯入

# %%
#%%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler

import joblib

import numpy as np
import pandas as pd
import os

# 設定LSTM往前看的筆數和預測筆數
LookBackNum = 12 # LSTM往前看的筆數
ForecastNum = 48 # 預測題目當天的筆數 9:00至16:59

# 載入訓練資料
DataName = os.getcwd() + '/L17_0331_9.csv'
# DataName = os.getcwd() + '/L1_0102_1.csv'
SourceData = pd.read_csv(DataName, encoding='utf-8')

#迴歸分析 選擇要留下來的資料欄位
#(風速,大氣壓力,溫度,濕度,光照度)
#(發電量)
Regression_X_train = SourceData[['WindSpeed(m/s)','Pressure(hpa)','Temperature(°C)','Humidity(%)','Sunlight(Lux)']].values
Regression_y_train = SourceData[['Power(mW)']].values

# 選擇要留下來的資料欄位
# (風速,大氣壓力,溫度,濕度,光照度)
AllOutPut = SourceData[['WindSpeed(m/s)','Pressure(hpa)','Temperature(°C)','Humidity(%)','Sunlight(Lux)']].values

# 正規化
LSTM_MinMaxModel = MinMaxScaler().fit(AllOutPut)
AllOutPut_MinMax = LSTM_MinMaxModel.transform(AllOutPut)
X_train = []
y_train = []

#設定每i-12筆資料(X_train)就對應到第i筆資料(y_train)
for i in range(LookBackNum,len(AllOutPut_MinMax)):
  # 這裡的 i 起啟值為 LookBackNum，所以 i-LookBackNum:i 就會變成 0:LookBackNum 取前 LookBackNum 筆資料
  X_train.append(AllOutPut_MinMax[i-LookBackNum:i, :])
  # 將取下一筆資料當目標標籤
  y_train.append(AllOutPut_MinMax[i, :])

X_train = np.array(X_train)
y_train = np.array(y_train)

# Reshaping
#(samples 是訓練樣本數量,timesteps 是每個樣本的時間步長,features 是每個時間步的特徵數量)
X_train = np.reshape(X_train,(X_train.shape [0], X_train.shape [1], 5))

print(X_train.shape)
# Out:
# (540, 12, 5)

# %% [markdown]
# # 建置LSTM模型&訓練模型

# %%
#%%
#============================建置&訓練模型============================
#建置LSTM模型

regressor = Sequential ()

regressor.add(LSTM(units = 256, return_sequences = True, input_shape = (X_train.shape[1], 5)))

regressor.add(LSTM(units = 128))

regressor.add(Dropout(0.3))

# output layer
regressor.add(Dense(units = 5))
learning_rate = 0.01  # 學習率
optimizer = Adam(learning_rate=learning_rate)
regressor.compile(optimizer = optimizer, loss = 'mean_squared_error')

#開始訓練
regressor.fit(X_train, y_train, epochs = 300, batch_size = 64)

#保存模型
# from datetime import datetime
# NowDateTime = datetime.now().strftime("%Y-%m-%dT%H_%M_%SZ")
regressor.save('WheatherLSTM_Model.h5')
print('Model Saved')
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - loss: 0.2490
# Epoch 2/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0802
# Epoch 3/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0288
# Epoch 4/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0177
# Epoch 5/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0152
# Epoch 6/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0117
# Epoch 7/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0115
# Epoch 8/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0105
# Epoch 9/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0097
# Epoch 10/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.0094
# Epoch 11/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.0083
# Epoch 12/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.0084
# Epoch 13/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - loss: 0.0075
# Epoch 14/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0070
# Epoch 15/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0065
# Epoch 16/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0062
# Epoch 17/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0062
# Epoch 18/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0057
# Epoch 19/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0051
# Epoch 20/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0053
# Epoch 21/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0047
# Epoch 22/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0045
# Epoch 23/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0051
# Epoch 24/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0046
# Epoch 25/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0049
# Epoch 26/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 0.0046
# Epoch 27/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.0043
# Epoch 28/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 0.0044
# Epoch 29/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0041
# Epoch 30/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0044
# Epoch 31/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0045
# Epoch 32/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0041
# Epoch 33/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0042
# Epoch 34/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0043
# Epoch 35/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0037
# Epoch 36/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0039
# Epoch 37/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0042
# Epoch 38/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0038
# Epoch 39/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.0035
# Epoch 40/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.0041
# Epoch 41/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 0.0042
# Epoch 42/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0039
# Epoch 43/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0038
# Epoch 44/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0038
# Epoch 45/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0042
# Epoch 46/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0039
# Epoch 47/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0039
# Epoch 48/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0035
# Epoch 49/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0038
# Epoch 50/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0033
# Epoch 51/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.0033
# Epoch 52/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 0.0038
# Epoch 53/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0035
# Epoch 54/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0040
# Epoch 55/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0036
# Epoch 56/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0036
# Epoch 57/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0040
# Epoch 58/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0033
# Epoch 59/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0034
# Epoch 60/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0035
# Epoch 61/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0032
# Epoch 62/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0035
# Epoch 63/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0033
# Epoch 64/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0033
# Epoch 65/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.0031
# Epoch 66/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 0.0033
# Epoch 67/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0030
# Epoch 68/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0034
# Epoch 69/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0029
# Epoch 70/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0030
# Epoch 71/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0032
# Epoch 72/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0032
# Epoch 73/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0035
# Epoch 74/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0029
# Epoch 75/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0028
# Epoch 76/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0031
# Epoch 77/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0031
# Epoch 78/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.0033
# Epoch 79/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.0030
# Epoch 80/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0032
# Epoch 81/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0030
# Epoch 82/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0035
# Epoch 83/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0030
# Epoch 84/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0032
# Epoch 85/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0032
# Epoch 86/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0032
# Epoch 87/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0029
# Epoch 88/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0033
# Epoch 89/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0029
# Epoch 90/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.0030
# Epoch 91/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - loss: 0.0027
# Epoch 92/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.0028
# Epoch 93/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0033
# Epoch 94/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0027
# Epoch 95/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0030
# Epoch 96/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0028
# Epoch 97/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0029
# Epoch 98/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0032
# Epoch 99/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0028
# Epoch 100/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0029
# Epoch 101/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0029
# Epoch 102/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0026
# Epoch 103/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 0.0028
# Epoch 104/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.0029
# Epoch 105/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 0.0026
# Epoch 106/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0030
# Epoch 107/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0029
# Epoch 108/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0027
# Epoch 109/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0029
# Epoch 110/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0028
# Epoch 111/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0027
# Epoch 112/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0030
# Epoch 113/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0029
# Epoch 114/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0026
# Epoch 115/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0028
# Epoch 116/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 0.0029
# Epoch 117/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - loss: 0.0029
# Epoch 118/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0027
# Epoch 119/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0031
# Epoch 120/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0031
# Epoch 121/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0025
# Epoch 122/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0025
# Epoch 123/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0028
# Epoch 124/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0028
# Epoch 125/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0024
# Epoch 126/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0028
# Epoch 127/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0029
# Epoch 128/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0027
# Epoch 129/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0029
# Epoch 130/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0026
# Epoch 131/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.0029
# Epoch 132/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0028
# Epoch 133/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0027
# Epoch 134/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0026
# Epoch 135/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0026
# Epoch 136/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0026
# Epoch 137/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0028
# Epoch 138/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0025
# Epoch 139/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0026
# Epoch 140/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0028
# Epoch 141/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0026
# Epoch 142/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.0029
# Epoch 143/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 0.0029
# Epoch 144/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0
300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0022
# Epoch 269/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0024
# Epoch 270/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0020
# Epoch 271/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0022
# Epoch 272/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0021
# Epoch 273/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0021
# Epoch 274/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0021
# Epoch 275/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0019
# Epoch 276/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0020
# Epoch 277/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 0.0018
# Epoch 278/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.0020
# Epoch 279/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - loss: 0.0022
# Epoch 280/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0017
# Epoch 281/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0020
# Epoch 282/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0021
# Epoch 283/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0019
# Epoch 284/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0019
# Epoch 285/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0021
# Epoch 286/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0017
# Epoch 287/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0018
# Epoch 288/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0018
# Epoch 289/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0019
# Epoch 290/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0020
# Epoch 291/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.0016
# Epoch 292/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0016
# Epoch 293/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 0.0018
# Epoch 294/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0017
# Epoch 295/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0018
# Epoch 296/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0019
# Epoch 297/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0016
# Epoch 298/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0017
# Epoch 299/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0018
# Epoch 300/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0016
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved

# %% [markdown]
# # 建置&訓練「回歸模型」

# %%
#%%
#============================建置&訓練「回歸模型」========================
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
#開始迴歸分析(對發電量做迴歸)
RegressionModel = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=5)
RegressionModel.fit(LSTM_MinMaxModel.transform(Regression_X_train), Regression_y_train)

#儲存回歸模型
# from datetime import datetime
# NowDateTime = datetime.now().strftime("%Y-%m-%dT%H_%M_%SZ")
joblib.dump(RegressionModel, 'WheatherRegression_Model')

# 取得 R squared 分數
print('R squared: ', RegressionModel.score(LSTM_MinMaxModel.transform(Regression_X_train), Regression_y_train))

# 取得特徵重要性
print('Feature importances: ', RegressionModel.feature_importances_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# R squared:  0.9998284633586986
# Feature importances:  [0.         0.01051917 0.01880962 0.00710058 0.96357063]

# %% [markdown]
# # 預測數據

# %%
# %%
#============================預測數據============================

#載入模型
regressor = load_model('WheatherLSTM_Model.h5')
Regression = joblib.load('WheatherRegression_Model')

inputs = [] # 存放參考資料
PredictOutput = []  # 存放預測值
PredictPower = [] #存放預測值(發電量)

# 取輸入資料的最後 LookBackNum 筆
TempData = AllOutPut[-LookBackNum:].reshape(LookBackNum, 5)  # (12, 5)
TempData = LSTM_MinMaxModel.transform(TempData) # 正規化
print("TempData.shape:", TempData.shape)
inputs = [TempData]  # 初始化 inputs，形狀為 (1, 12, 5)
print("inputs.shape:", np.array(inputs).shape)

# 預測迴圈
for i in range(ForecastNum) :

  #將新的預測值加入參考資料(用自己的預測值往前看)
  if i > 0 :
    # 將新的預測值加入 inputs
    PredictValue = PredictOutput[i-1].reshape(1, 5) # 預測值形狀為 (1, 5)
    NewInput = np.vstack((inputs[-1][1:], PredictValue))  # 拼接，保留最後 LookBackNum 筆
    inputs.append(NewInput)  # 確保形狀為 (12, 5)

  print(f"inputs[{i}]: {[x.shape for x in inputs]}")
  print(f"type(inputs[-1]): {type(inputs[-1])}")

  # 從 inputs 提取新的參考資料12筆(往前看12筆)
  X_test = np.array(inputs[-1])  # 使用最新的 inputs，形狀為 (12, 5)
  X_test = np.reshape(X_test, (1, LookBackNum, 5))  # 確保形狀為 (batch_size, timesteps, features)

  print(f"X_test.shape: {X_test.shape}")

  # 預測
  predicted = regressor.predict(X_test) # 預測輸出形狀 (1, 5)
  print("predicted.shape:", predicted.shape)
  PredictOutput.append(predicted)
  PredictPower.append(np.round(Regression.predict(predicted),2).flatten())

# 最後檢查輸出
print("Final PredictOutput.shape:", np.array(PredictOutput).shape)
print("Final PredictPower.shape:", np.array(PredictPower).shape)

#寫預測結果寫成新的CSV檔案
# 將陣列轉換為 DataFrame
df = pd.DataFrame(PredictPower, columns=['答案'])

# 將 DataFrame 寫入 CSV 檔案
df.to_csv('output.csv', index=False, encoding='utf-8-sig')
print('Output CSV File Saved')

# %%
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# TempData.shape: (36, 5)
# inputs.shape: (1, 36, 5)
# inputs[0]: [(36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# predicted.shape: (1, 5)
# inputs[1]: [(36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predicted.shape: (1, 5)
# inputs[2]: [(36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predicted.shape: (1, 5)
# inputs[3]: [(36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predicted.shape: (1, 5)
# inputs[4]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predicted.shape: (1, 5)
# inputs[5]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predicted.shape: (1, 5)
# inputs[6]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# predicted.shape: (1, 5)
# inputs[7]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predicted.shape: (1, 5)
# inputs[8]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predicted.shape: (1, 5)
# inputs[9]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predicted.shape: (1, 5)
# inputs[10]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predicted.shape: (1, 5)
# inputs[11]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predicted.shape: (1, 5)
# inputs[12]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predicted.shape: (1, 5)
# inputs[13]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predicted.shape: (1, 5)
# inputs[14]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predicted.shape: (1, 5)
# inputs[15]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predicted.shape: (1, 5)
# inputs[16]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# predicted.shape: (1, 5)
# inputs[17]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predicted.shape: (1, 5)
# inputs[18]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predicted.shape: (1, 5)
# inputs[19]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predicted.shape: (1, 5)
# inputs[20]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predicted.shape: (1, 5)
# inputs[21]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predicted.shape: (1, 5)
# inputs[22]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predicted.shape: (1, 5)
# inputs[23]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predicted.shape: (1, 5)
# inputs[24]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predicted.shape: (1, 5)
# inputs[25]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predicted.shape: (1, 5)
# inputs[26]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# predicted.shape: (1, 5)
# inputs[27]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# predicted.shape: (1, 5)
# inputs[28]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predicted.shape: (1, 5)
# inputs[29]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predicted.shape: (1, 5)
# inputs[30]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predicted.shape: (1, 5)
# inputs[31]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predicted.shape: (1, 5)
# inputs[32]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predicted.shape: (1, 5)
# inputs[33]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predicted.shape: (1, 5)
# inputs[34]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predicted.shape: (1, 5)
# inputs[35]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predicted.shape: (1, 5)
# inputs[36]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# predicted.shape: (1, 5)
# inputs[37]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predicted.shape: (1, 5)
# inputs[38]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predicted.shape: (1, 5)
# inputs[39]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# predicted.shape: (1, 5)
# inputs[40]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# predicted.shape: (1, 5)
# inputs[41]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# predicted.shape: (1, 5)
# inputs[42]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# predicted.shape: (1, 5)
# inputs[43]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# predicted.shape: (1, 5)
# inputs[44]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# predicted.shape: (1, 5)
# inputs[45]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# predicted.shape: (1, 5)
# inputs[46]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# predicted.shape: (1, 5)
# inputs[47]: [(36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5), (36, 5)]
# type(inputs[-1]): <class 'numpy.ndarray'>
# X_test.shape: (1, 36, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# predicted.shape: (1, 5)
# Final PredictOutput.shape: (48, 1, 5)
# Final PredictPower.shape: (48, 1)
# Output CSV File Saved
